# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %%
tienda.sample(5)
# Out:
#                  Producto Categoría del Producto    Precio  Costo de envío  \
# 1036        Juego de mesa               Juguetes  166100.0         13600.0
# 2253  Modelado predictivo                 Libros   65300.0          1700.0
# 1602            Bicicleta   Deportes y diversión  504500.0         27300.0
# 1491            Bicicleta   Deportes y diversión  516600.0         33400.0
# 641          Vaso térmico   Deportes y diversión   57800.0          5500.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 1036      30/01/2023  Beatriz Morales         Pereira             1
# 2253      18/06/2022    Juliana Costa          Bogotá             5
# 1602      19/05/2020  Mariana Herrera          Bogotá             3
# 1491      25/07/2021  Izabela de León       Manizales             4
# 641       11/11/2022  Beatriz Morales          Bogotá             5
#
#           Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
tienda2.sample(5)
# Out:
#              Producto   Categoría del Producto     Precio  Costo de envío  \
# 695       Muñeca bebé                 Juguetes    53600.0          1000.0
# 1154          Armario                  Muebles   516900.0         27900.0
# 962   Olla de presión  Artículos para el hogar    74000.0         11100.0
# 2172       Microondas        Electrodomésticos   328000.0         17700.0
# 171           Batería   Instrumentos musicales  1026100.0         52800.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 695       19/03/2021   Juan Fernandez          Bogotá             1
# 1154      16/07/2022  Beatriz Morales          Bogotá             1
# 962       22/01/2023   Blanca Ramirez        Medellín             5
# 2172      25/08/2022    Camila Rivera       Cartagena             1
# 171       22/02/2021    Juliana Costa       Manizales             5
#
#           Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
tienda3.sample(5)
# Out:
#                        Producto Categoría del Producto    Precio  \
# 771     Dashboards con Power BI                 Libros   29800.0
# 401   Iniciando en programación                 Libros   34600.0
# 36                    Bicicleta   Deportes y diversión  316900.0
# 1068             Mesa de centro                Muebles  184900.0
# 79           Cuerda para saltar   Deportes y diversión   17100.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 771           2000.0      03/11/2021  Izabela de León        Medellín
# 401              0.0      05/01/2020    Lucas Olivera            Cali
# 36           15100.0      25/11/2021    Felipe Santos          Bogotá
# 1068         10100.0      04/12/2022   Blanca Ramirez          Bogotá
# 79            1100.0      30/08/2021    Camila Rivera          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
tienda4.sample(5)
# Out:
#                      Producto Categoría del Producto     Precio  \
# 1925  Bloques de construcción               Juguetes    41700.0
# 745                  Smart TV           Electrónicos  1134400.0
# 1208              Muñeca bebé               Juguetes    58000.0
# 1586             Refrigerador      Electrodomésticos  2351000.0
# 1040        Asistente virtual           Electrónicos   127400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 1925             0.0      23/03/2023  Beatriz Morales          Bogotá
# 745          65200.0      23/08/2021  Mariana Herrera        Medellín
# 1208          3500.0      09/08/2022   Blanca Ramirez        Medellín
# 1586        125400.0      26/04/2022   Blanca Ramirez        Medellín
# 1040         12800.0      20/08/2021    Felipe Santos          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas      lat       lon
# 1925             4  Tarjeta de crédito                   9  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_total_tienda1 = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()

# %%
print(ingreso_total_tienda1)
print(ingreso_total_tienda2)
print(ingreso_total_tienda3)
print(ingreso_total_tienda4)
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria1 = tienda.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_por_categoria2 = tienda2.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_por_categoria3 = tienda3.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_por_categoria4 = tienda4.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)

# %%
print(ventas_por_categoria1)
print(ventas_por_categoria2)
print(ventas_por_categoria3)
print(ventas_por_categoria4)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# Instrumentos musicales     177
# Name: Producto, dtype: int64
# Categoría del Producto
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio1 = tienda['Calificación'].mean()
calificacion_promedio2 = tienda2['Calificación'].mean()
calificacion_promedio3 = tienda3['Calificación'].mean()
calificacion_promedio4 = tienda4['Calificación'].mean()

# %%
print(calificacion_promedio1)
print(calificacion_promedio2)
print(calificacion_promedio3)
print(calificacion_promedio4)
# Out:
# 3.976685036032217
# 4.037303942348453
# 4.048325561678677
# 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_mas_vendido1 = tienda.groupby('Producto')['Producto'].count().sort_values(ascending=False)
producto_mas_vendido2 = tienda2.groupby('Producto')['Producto'].count().sort_values(ascending=False)
producto_mas_vendido3 = tienda3.groupby('Producto')['Producto'].count().sort_values(ascending=False)
producto_mas_vendido4 = tienda4.groupby('Producto')['Producto'].count().sort_values(ascending=False)

# %%
print(producto_mas_vendido1.head(5))
print()
print(producto_mas_vendido1.tail(5))
print()
print(producto_mas_vendido2.head(5))
print()
print(producto_mas_vendido2.tail(5))
print()
print(producto_mas_vendido3.head(5))
print()
print(producto_mas_vendido3.tail(5))
print()
print(producto_mas_vendido4.head(5))
print()
print(producto_mas_vendido4.tail(5))
# Out:
# Producto
# Armario             60
# TV LED UHD 4K       60
# Microondas          60
# Secadora de ropa    58
# Mesa de noche       56
# Name: Producto, dtype: int64
#
# Producto
# Mochila                      39
# Pandereta                    36
# Olla de presión              35
# Celular ABXY                 33
# Auriculares con micrófono    33
# Name: Producto, dtype: int64
#
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Pandereta                    58
# Guitarra acústica            58
# Name: Producto, dtype: int64
#
# Producto
# Auriculares        37
# Sillón             35
# Impresora          34
# Mesa de comedor    34
# Juego de mesa      32
# Name: Producto, dtype: int64
#
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: Producto, dtype: int64
#
# Producto
# Guitarra eléctrica         38
# Mochila                    36
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = tienda['Costo de envío'].mean()
envio_promedio2 = tienda2['Costo de envío'].mean()
envio_promedio3 = tienda3['Costo de envío'].mean()
envio_promedio4 = tienda4['Costo de envío'].mean()

# %%
print(envio_promedio)
print(envio_promedio2)
print(envio_promedio3)
print(envio_promedio4)
# Out:
# 26018.60958033065
# 25216.235693090293
# 24805.680373039424
# 23459.457167090754

# %% [markdown]
# # 6. Graficos

# %%
import numpy as np
import matplotlib.ticker as mticker

fig, ax = plt.subplots(figsize=(12, 6)) # Increased figure size for better visibility

# Example data
tiendas = ('Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4')
y_pos = np.arange(len(tiendas))
ganancias = [ingreso_total_tienda1, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4]

bars = ax.barh(y_pos, ganancias, align='center')
ax.set_yticks(y_pos, labels=tiendas)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Ingresos')
ax.set_title('Ingresos por tienda')

# Format x-axis labels to show values in billions
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: format(x/1000000000, '.1f') + 'B'))

# Set the major tick locations to every 0.05 Billion (50 million) for clearer intervals
ax.xaxis.set_major_locator(mticker.MultipleLocator(100000000)) # 50,000,000 is 0.05 Billion

# Set the x-axis limits to emphasize differences
ax.set_xlim(left=1000000000) # Setting the lower limit to 1 billion (1,000,000,000)

# Add the values of each bar inside the bar
for idx, bar in enumerate(bars):
    width = bar.get_width()
    ax.text(width - 10000000, bar.get_y() + bar.get_height()/2,    # (x,y) position
            f'{str(ganancias[idx]/1000000000)[:4] + 'B'}',                                   # format to 2 decimal place
            ha='right', va='center', color='white', weight='bold') # text alignment and style

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

fig, (ax, ax2, ax3, ax4) = plt.subplots(nrows=1,ncols=4,figsize=(16, 12), subplot_kw=dict(aspect="equal"))
#fig, ax2 = plt.subplots(figsize=(6, 6), subplot_kw=dict(aspect="equal"))

categorias = ventas_por_categoria1.index
valores = ventas_por_categoria1.values
valores2 = ventas_por_categoria2.values
valores3 = ventas_por_categoria3.values
valores4 = ventas_por_categoria4.values
explode = (0.05, 0, 0, 0, 0,0,0,0)
cmap_colors = cm.tab10.colors[:len(categorias)]

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute})"

wedges, texts, autotexts = ax.pie(valores,colors=cmap_colors, explode=explode, autopct=lambda pct: func(pct, valores), textprops=dict(color="w"))
wedges, texts, autotexts2 = ax2.pie(valores2,colors=cmap_colors, explode=explode, autopct=lambda pct: func(pct, valores2), textprops=dict(color="w"))
wedges, texts, autotexts3 = ax3.pie(valores3,colors=cmap_colors, explode=explode, autopct=lambda pct: func(pct, valores3), textprops=dict(color="w"))
wedges, texts, autotexts4 = ax4.pie(valores4,colors=cmap_colors, explode=explode, autopct=lambda pct: func(pct, valores4), textprops=dict(color="w"))

ax.legend(wedges, categorias,
          title="Categorias",
          loc="center left",
          bbox_to_anchor=(5, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")
plt.setp(autotexts2, size=8, weight="bold")
plt.setp(autotexts3, size=8, weight="bold")
plt.setp(autotexts4, size=8, weight="bold")

ax.set_title("Ventas por categoria Tienda 1")
ax2.set_title("Ventas por categoria Tienda 2")
ax3.set_title("Ventas por categoria Tienda 3")
ax4.set_title("Ventas por categoria Tienda 4")

plt.show()

# %%
import numpy as np
import matplotlib.ticker as mticker

fig, ax = plt.subplots(figsize=(12, 6))

tiendas = ('Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4')
puntuaciones = [calificacion_promedio1, calificacion_promedio2,
                calificacion_promedio3, calificacion_promedio4]
bar_colors = ['tab:blue', 'tab:orange', 'tab:red', 'tab:blue']

bars = ax.bar(tiendas, puntuaciones, color=bar_colors)

ax.set_ylabel('Promedio Puntuacion')
ax.set_title('Promedio Puntuacion por Tienda')
ax.set_ylim(bottom=3, top=5)

# Add the values of each bar inside the bar
for idx, bar in enumerate(bars):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height - 0.1,    # (x,y) position
            f'{str(puntuaciones[idx])[:4]}',
            ha='center', va='center', color='white', weight='bold')  # text alignment and style


plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mticker

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15, 6))
ax, ax2, ax3, ax4 = axs.flat

productos = pd.concat([producto_mas_vendido1.tail(
    5).sort_values(), producto_mas_vendido1.head(5).sort_values()])
nombres_productos = productos.index
puntuaciones = productos.values

productos2 = pd.concat([producto_mas_vendido2.tail(
    5).sort_values(), producto_mas_vendido2.head(5).sort_values()])
nombres_productos2 = productos2.index
puntuaciones2 = productos2.values

productos3 = pd.concat([producto_mas_vendido3.tail(
    5).sort_values(), producto_mas_vendido3.head(5).sort_values()])
nombres_productos3 = productos3.index
puntuaciones3 = productos3.values

productos4 = pd.concat([producto_mas_vendido4.tail(
    5).sort_values(), producto_mas_vendido4.head(5).sort_values()])
nombres_productos4 = productos4.index
puntuaciones4 = productos4.values

y_pos = np.arange(len(nombres_productos))

bars = ax.barh(y_pos, puntuaciones, align='center')
ax.set_yticks(y_pos, labels=nombres_productos)
ax.set_xlabel('Ventas')

bars2 = ax2.barh(y_pos, puntuaciones2, align='center')
ax2.set_yticks(y_pos, labels=nombres_productos2)
ax2.set_xlabel('Ventas')

bars3 = ax3.barh(y_pos, puntuaciones3, align='center')
ax3.set_yticks(y_pos, labels=nombres_productos3)
ax3.set_xlabel('Ventas')

bars4 = ax4.barh(y_pos, puntuaciones4, align='center')
ax4.set_yticks(y_pos, labels=nombres_productos4)
ax4.set_xlabel('Ventas')

ax.set_xlim(left=20)
ax2.set_xlim(left=20)
ax3.set_xlim(left=20)
ax4.set_xlim(left=20)

ax.set_title('Productos mas y menos vendidos Tienda 1')
ax2.set_title('Productos mas y menos vendidos Tienda 2')
ax3.set_title('Productos mas y menos vendidos Tienda 3')
ax4.set_title('Productos mas y menos vendidos Tienda 4')

# Add the values of each bar inside the bar
for idx, bar in enumerate(bars):
    width = bar.get_width()
    ax.text(width - 1, bar.get_y() + bar.get_height()/2,    # (x,y) position
            f'{str(puntuaciones[idx])[:4]}',
            ha='right', va='center', color='white', weight='bold')

for idx, bar in enumerate(bars2):
    width = bar.get_width()
    ax2.text(width - 1, bar.get_y() + bar.get_height()/2,    # (x,y) position
             f'{str(puntuaciones2[idx])[:4]}',
             ha='right', va='center', color='white', weight='bold')

for idx, bar in enumerate(bars3):
    width = bar.get_width()
    ax3.text(width - 1, bar.get_y() + bar.get_height()/2,    # (x,y) position
             f'{str(puntuaciones3[idx])[:4]}',
             ha='right', va='center', color='white', weight='bold')

for idx, bar in enumerate(bars4):
    width = bar.get_width()
    ax4.text(width - 1, bar.get_y() + bar.get_height()/2,    # (x,y) position
             f'{str(puntuaciones4[idx])[:4]}',
             ha='right', va='center', color='white', weight='bold')

plt.tight_layout()  # Adjust layout to prevent labels from being cut off
plt.show()

# %% [markdown]
# # Informe
#
# ## **Introduccion**
# El objetivo de este desafio es analizar datos relacionados a **4 tiendas** para poder decidir cual conviene mas vender.
#
# ## **Desarrollo**
# Para lograr ese objetivo se tuvo acceso a una base de datos con informacion relacionada a las ventas de cada tienda. Con esa informacion se hicieron analisis de: Los **ingresos totales** de las tiendas, las **categorías** de productos más y menos vendidas, las **calificaciones** promedio de los clientes por tienda,los **productos** más y menos **vendidos** y el **coste de envío** promedio para cada tienda.
# A base de ese analisis se crearon unos graficos para ayudar visualizar los datos y justificar la decision tomada.
#
# ### **Graficos**
#
#
# 1. Si analizamos los ingresos de cada tienda podemos ver que la tienda con menor ganancias es la **Tienda 4**, ganando unos 110 millones menos que la **Tienda 1**
#   ![download.png](data:image/png;base64,...)
# 2.   Si analizamos la distribucion de las ventas por categoria de productos en las 4 tiendas podemos apreciar que no hay mucha diferencia, manteniendose siempre la categoria **Muebles** como la mas vendida.
# ![image.png](data:image/png;base64,...)
# 3. Si calculamos el promedio de las puntuaciones en cada tienda veremos que no hay gran diferencia que nos pueda ayudar a tomar una decision.
# ![image.png](data:image/png;base64,...)
#
# 4. Analizar los productos mas y menos vendidos de cada tienda podemos ver como los Muebles, Electronicos y Eletrodomesticos dominan las ventas.
# ![image.png](data:image/png;base64,...)
#
# # Conclusion
#
# Basado en los graficos y otros analises realizados la unica metrica que destaca y que podria ser utilizada para tomar una decision es las ventas totales.
#
# Por lo cual mi recomendacion es vender la **Tienda 4** la cual tiene las menores ventas de las 4 tiendas.
